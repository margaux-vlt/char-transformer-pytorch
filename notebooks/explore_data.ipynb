# %% [markdown]
# # Exploration of dataset

# %%
import requests

# Example: Alice in Wonderland
url = "https://www.gutenberg.org/files/11/11-0.txt"
text = requests.get(url).text

# Optional: remove Gutenberg header/footer
start = text.find("*** START OF THIS PROJECT GUTENBERG EBOOK")
end = text.find("*** END OF THIS PROJECT GUTENBERG EBOOK")
if start != -1 and end != -1:
    text = text[start:end]

# Save locally
with open("data/alice_in_wonderland.txt", "w", encoding="utf-8") as f:
    f.write(text)

print("Length of text:", len(text))
print(text[:500])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 14
#      11     text = text[start:end]
#      13 # Save locally
# ---> 14 with open("data/alice_in_wonderland.txt", "w", encoding="utf-8") as f:
#      15     f.write(text)
#      17 print("Length of text:", len(text))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mpm2025/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/alice_in_wonderland.txt'
